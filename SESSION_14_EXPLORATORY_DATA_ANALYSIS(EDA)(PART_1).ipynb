# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Q1. Download a small dataset of IPL cricket matches (CSV or Excel), load it into a pandas DataFrame, and perform univariate analysis by printing the summary statistics (mean, median, min, max, std) for the 'total_runs' column.

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/ipl_2008_2024_complete.csv")

print(df.head())

print("\nSummary Statistics for Total Runs:")

print("Mean   :", df["total_runs"].mean())
print("Median :", df["total_runs"].median())
print("Minimum:", df["total_runs"].min())
print("Maximum:", df["total_runs"].max())
print("Std    :", df["total_runs"].std())
# Out:
#    match_id  innings  total_runs  extras  wickets  balls_bowled  boundaries_4  \
# 0    335982        1         205      17        3           124            15
# 1    335982        2          63      19       10           101             3
# 2    335983        1         234       6        5           124            20
# 3    335983        2         196      11        4           124            18
# 4    335984        1         122       7        8           122            14
#
#    boundaries_6  dot_balls                 batting_team  ...        date  \
# 0            14         45        Kolkata Knight Riders  ...  2008-04-18
# 1             3         65  Royal Challengers Bangalore  ...  2008-04-18
# 2            16         39          Chennai Super Kings  ...  2008-04-19
# 3             9         33              Kings XI Punjab  ...  2008-04-19
# 4             3         60             Rajasthan Royals  ...  2008-04-19
#
#                                         venue        city  \
# 0                       M Chinnaswamy Stadium   Bangalore
# 1                       M Chinnaswamy Stadium   Bangalore
# 2  Punjab Cricket Association Stadium, Mohali  Chandigarh
# 3  Punjab Cricket Association Stadium, Mohali  Chandigarh
# 4                            Feroz Shah Kotla       Delhi
#
#                    toss_winner  toss_decision                 winner  \
# 0  Royal Challengers Bangalore          field  Kolkata Knight Riders
# 1  Royal Challengers Bangalore          field  Kolkata Knight Riders
# 2          Chennai Super Kings            bat    Chennai Super Kings
# 3          Chennai Super Kings            bat    Chennai Super Kings
# 4             Rajasthan Royals            bat       Delhi Daredevils
#
#    player_of_match  method  season toss_win_match_win
# 0      BB McCullum     NaN  2008.0                0.0
# 1      BB McCullum     NaN  2008.0                0.0
# 2       MEK Hussey     NaN  2008.0                1.0
# 3       MEK Hussey     NaN  2008.0                1.0
# 4      MF Maharoof     NaN  2008.0                0.0
#
# [5 rows x 28 columns]
#
# Summary Statistics for Total Runs:
# Mean   : 148.8786648624267
# Median : 151.0
# Minimum: 1
# Maximum: 272
# Std    : 35.70165915033417

# %% [markdown]
# Q2. Using a dataset of Flipkart product reviews (at least columns: 'rating', 'category'), create a bar plot showing the count of reviews for each rating (1-5 stars) using matplotlib or seaborn.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file_path = "/content/drive/MyDrive/tops/flipkart_reviews.csv"

df = pd.read_csv(file_path)

print(df.head())

rating_counts = df["rating"].value_counts().sort_index()

print("\nReview count for each rating:")
print(rating_counts)

plt.figure(figsize=(8, 5))
sns.barplot(x=rating_counts.index, y=rating_counts.values)

plt.title("Number of Flipkart Reviews by Rating")
plt.xlabel("Rating (Stars)")
plt.ylabel("Number of Reviews")
plt.show()
# Out:
#    rating     category
# 0       5  Electronics
# 1       4      Fashion
# 2       5  Electronics
# 3       3         Home
# 4       4      Fashion
#
# Review count for each rating:
# rating
# 1    2
# 2    2
# 3    3
# 4    6
# 5    7
# Name: count, dtype: int64

# %% [markdown]
# Q3. Take a dataset of Zomato restaurant listings (with 'average_cost_for_two' and 'user_rating' columns) and create a scatterplot to visualize the relationship between cost and user rating.<br><br><em><strong>Hint:</strong> Use seaborn's scatterplot() function and label the axes clearly.</em>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/MyDrive/tops/zomato_restaurants.csv")

print(df.head())

plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="average_cost_for_two",
    y="user_rating"
)

plt.title("Relationship Between Cost and User Rating")
plt.xlabel("Average Cost for Two")
plt.ylabel("User Rating")

plt.show()
# Out:
#   restaurant_name  average_cost_for_two  user_rating
# 0    Spice Garden                   500          4.2
# 1   Food Junction                   800          4.0
# 2    Cafe Delight                   350          3.8
# 3     Urban Bites                  1200          4.5
# 4  The Food House                   650          3.9

# %% [markdown]
# Q4. For a BookMyShow movie dataset (with 'genre' and 'box_office_collection' columns), use groupby analysis to find the average box office collection for each genre and display the results as a sorted table.

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/tops/bookmyshow_movies.csv"
df = pd.read_csv(file_path)

print("BookMyShow Movie Dataset:")
print(df.head())

result = (
    df.groupby("genre")["box_office_collection"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

print("\nAverage Box Office Collection for Each Genre:")
print(result)
# Out:
# BookMyShow Movie Dataset:
#   movie_name   genre  box_office_collection
# 0    Movie A  Action                    250
# 1    Movie B  Comedy                    180
# 2    Movie C  Action                    320
# 3    Movie D   Drama                    200
# 4    Movie E  Comedy                    150
#
# Average Box Office Collection for Each Genre:
#     genre  box_office_collection
# 0  Action             283.333333
# 1   Drama             210.000000
# 2  Comedy             173.333333
# 3  Horror             140.000000

# %% [markdown]
# Q5.Use the seaborn 'pairplot' function on a Spotify songs dataset (with at least 'danceability', 'energy', 'valence', and 'popularity' columns) to visualize pairwise relationships between these features. Briefly describe one interesting pattern you observe.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
file_path = "/content/drive/MyDrive/tops/spotify_songs.csv"
df = pd.read_csv(file_path)

features = [
    "danceability",
    "energy",
    "valence",
    "popularity"
]

print(df[features].head())

sns.pairplot(df[features])

plt.show()
# Out:
#    danceability  energy  valence  popularity
# 0          0.51    0.73     0.33          95
# 1          0.83    0.65     0.93          92
# 2          0.70    0.83     0.92          88
# 3          0.59    0.76     0.48          91
# 4          0.70    0.43     0.56          89
