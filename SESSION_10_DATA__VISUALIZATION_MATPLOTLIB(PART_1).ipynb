# %% [markdown]
# Q1. Install Matplotlib in your Python environment and create a simple line plot showing the number of daily steps you took over the last 7 days. Save the chart as steps_lineplot.png.

# %%
import matplotlib.pyplot as plt
days = ["Monday", "Tuesday", "Wednesday", "Thursday",
        "Friday", "Saturday", "Sunday"]
steps = [6500, 8200, 7100, 9000, 7800, 10500, 8500]
plt.plot(days, steps, marker="o")
plt.xlabel("Day")
plt.ylabel("Number of Steps")
plt.title("Daily Steps - Last 7 Days")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("steps_lineplot.png")
plt.show()

# %% [markdown]
# Q2. Using Matplotlib, create a scatter plot of 10 restaurants from your city with their Zomato ratings on the x-axis and average meal price on the y-axis. Add axis labels and a title to the chart.

# %%
import matplotlib.pyplot as plt
restaurants = [
    "Agashiye",
    "Gordhan Thal",
    "Swati Snacks",
    "The Green House",
    "Sankalp",
    "Atithi",
    "Honest",
    "Barbeque Nation",
    "Mocha",
    "650 - The Global Kitchen"
]
ratings = [4.5, 4.3, 4.4, 4.2, 4.1, 4.0, 4.2, 4.4, 4.1, 4.3]
prices = [1200, 700, 600, 800, 500, 700, 400, 900, 800, 1000]
plt.scatter(ratings, prices)
plt.xlabel("Zomato Rating")
plt.ylabel("Average Meal Price (₹)")
plt.title("Zomato Ratings vs Average Meal Price - Ahmedabad")
plt.show()

# %% [markdown]
# Q3. Build a bar chart that shows the number of orders you or your friends placed on Swiggy, Zomato, and Domino’s in the last month. Use different colors for each bar and add a legend.

# %%
import matplotlib.pyplot as plt
platforms = ["Swiggy", "Zomato", "Domino's"]
orders = [12, 9, 6]
colors = ["red", "orange", "blue"]
plt.bar(platforms, orders, color=colors, label=platforms)
plt.xlabel("Food Delivery Platform")
plt.ylabel("Number of Orders")
plt.title("Food Delivery Orders - Last Month")
plt.legend()
plt.show()

# %% [markdown]
# Q4. Create a histogram of the durations (in minutes) of your last 20 Spotify listening sessions using Matplotlib. Set the number of bins to 5 and customize the color of the bars.

# %%
import matplotlib.pyplot as plt
durations = [
    25, 40, 35, 50, 45,
    30, 60, 55, 20, 35,
    42, 48, 65, 70, 28,
    33, 52, 45, 38, 58
]
plt.hist(durations, bins=5, color="purple", edgecolor="black")
plt.xlabel("Listening Duration (Minutes)")
plt.ylabel("Number of Sessions")
plt.title("Spotify Listening Session Durations")
plt.show()

# %% [markdown]
# Q5. Customize a Matplotlib figure by creating a plot with two subplots: one line plot showing your daily Instagram screen time for a week, and one bar chart showing the number of posts you liked each day. Add appropriate titles, axis labels, and save the figure as social_media_usage.png.<br><br><em><strong>Hint:</strong> Use plt.subplots() to create multiple axes in one figure.</em>

# %%
import matplotlib.pyplot as plt
days = ["Monday", "Tuesday", "Wednesday", "Thursday",
        "Friday", "Saturday", "Sunday"]
screen_time = [2.5, 3.0, 2.8, 3.5, 4.0, 4.5, 3.2]
likes = [15, 20, 18, 25, 30, 35, 22]
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(days, screen_time, marker="o")
axes[0].set_title("Daily Instagram Screen Time")
axes[0].set_xlabel("Day")
axes[0].set_ylabel("Screen Time (Hours)")
axes[0].tick_params(axis="x", rotation=45)
axes[1].bar(days, likes, color="orange")
axes[1].set_title("Instagram Posts Liked Each Day")
axes[1].set_xlabel("Day")
axes[1].set_ylabel("Number of Posts Liked")
axes[1].tick_params(axis="x", rotation=45)
plt.tight_layout()
plt.savefig("social_media_usage.png")
plt.show()
