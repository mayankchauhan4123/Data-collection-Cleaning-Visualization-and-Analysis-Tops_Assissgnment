# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
import numpy as np

# %%
#Q2
followers = np.array([1200, 15000, 67000, 340000, 1250000])

print("Followers Array:")
print(followers)

print("\nShape:", followers.shape)
print("Dimensions:", followers.ndim)
print("Data Type:", followers.dtype)
# Out:
# Followers Array:
# [   1200   15000   67000  340000 1250000]
#
# Shape: (5,)
# Dimensions: 1
# Data Type: int64

# %%
#Q3
order_ids = np.arange(101, 111)

print("Order IDs:")
print(order_ids)

print("\nSize:", order_ids.size)
# Out:
# Order IDs:
# [101 102 103 104 105 106 107 108 109 110]
#
# Size: 10

# %%
#Q4
like_matrix = np.eye(3)

print("Identity Matrix:")
print(like_matrix)
# Out:
# Identity Matrix:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
#Q5
scores = [45, 67, 120, 89, 54]

score_array = np.array(scores)

print("Cricket Scores:")
print(score_array)

print("\nMemory used by each score:", score_array.itemsize, "bytes")
# Out:
# Cricket Scores:
# [ 45  67 120  89  54]
#
# Memory used by each score: 8 bytes
